# %% [markdown]
# <a href="https://colab.research.google.com/github/sir-sauc3/cap-comp215/blob/main/Lab3_neo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMP 215 - LAB 2 (NEO)
# ----------------
# #### Name: Sos & Roberto
# #### Date: Jan 16 2023
#
# This lab exercise is mostly a review of strings, tuples, lists, dictionaries, and functions.
#
# **Building on new concepts from lab 1**:
#   * *f-string* simplifies string formatting operations (like, a lot!)
#   * *list comprehension* provides a compact way to represent map and filter algorithms
#
# **New Python Concepts**:
#   * *f-string* simplifies string formatting operations (like, a lot!)
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import datetime, json, requests
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# We'll answer some questions about [Near Earth Objects](https://cneos.jpl.nasa.gov/)
# > using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS)
#
# You should register for your own API key, (but may use the DEMO_KEY to get started).
#
# First we need a short tutorial on python dates and [f-strings](https://realpython.com/python-f-strings/)...

# %%
today = datetime.date.today()   # get a date object representing today's date
print(today, type(today))
formatted_date = f'Today is: {today}'   # A format string - notice how the variable `today` is formatted into the stringg
print(formatted_date)
# Out:
# 2023-01-25 <class 'datetime.date'>
# Today is: 2023-01-25

# %% [markdown]
# ### Make a query
#
# Let's get some data from the NEO database...
# Here's a query that gets the observation "feed" for today:

# %%
API_KEY = 'ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'  # substitute your API key here

today = '2023-01-09'   # Today's date as a string!
# Use an f-string here to "format" the date and API key varaibles.
url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={today}&end_date={today}&api_key={API_KEY}'

response = requests.request("GET", url, headers={}, data={})

data = json.loads(response.text)  # recall json.loads for lab 1

# TIP: print(data) to see the whole data structure returned, here we grab just the list of NEO's:
n_results = data['element_count']
neos = data['near_earth_objects'][today]
print(f'{n_results} Near Earth Objects found for {today}')
pprint(neos)
# Out:
# 12 Near Earth Objects found for 2023-01-09
# [{'absolute_magnitude_h': 19.64,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 13:59',
#                            'epoch_date_close_approach': 1673272740000,
#                            'miss_distance': {'astronomical': '0.0725377631',
#                                              'kilometers': '10851494.854324597',
#                                              'lunar': '28.2171898459',
#                                              'miles': '6742806.2343975586'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '32387.3201949256',
#                                                  'kilometers_per_second': '8.9964778319',
#                                                  'miles_per_hour': '20124.2212622303'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 2301.5744618737,
#                                   'estimated_diameter_min': 1029.2953904054},
#                          'kilometers': {'estimated_diameter_max': 0.7015198735,
#                                         'estimated_diameter_min': 0.313729225},
#                          'meters': {'estimated_diameter_max': 701.5198735305,
#                                     'estimated_diameter_min': 313.7292249562},
#                          'miles': {'estimated_diameter_max': 0.4359041053,
#                                    'estimated_diameter_min': 0.1949422422}},
#   'id': '2226554',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '226554 (2003 WR21)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2226554',
#   'neo_reference_id': '2226554'},
#  {'absolute_magnitude_h': 20.62,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 16:33',
#                            'epoch_date_close_approach': 1673281980000,
#                            'miss_distance': {'astronomical': '0.2884780108',
#                                              'kilometers': '43155695.957516996',
#                                              'lunar': '112.2179462012',
#                                              'miles': '26815706.0071907048'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '30014.4391606086',
#                                                  'kilometers_per_second': '8.3373442113',
#                                                  'miles_per_hour': '18649.8052662126'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1465.6323083572,
#                                   'estimated_diameter_min': 655.4506943013},
#                          'kilometers': {'estimated_diameter_max': 0.4467247133,
#                                         'estimated_diameter_min': 0.1997813652},
#                          'meters': {'estimated_diameter_max': 446.7247132921,
#                                     'estimated_diameter_min': 199.78136523},
#                          'miles': {'estimated_diameter_max': 0.2775817818,
#                                    'estimated_diameter_min': 0.1241383467}},
#   'id': '2307070',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2307070?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '307070 (2002 AV31)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2307070',
#   'neo_reference_id': '2307070'},
#  {'absolute_magnitude_h': 18.4,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 01:00',
#                            'epoch_date_close_approach': 1673226000000,
#                            'miss_distance': {'astronomical': '0.3628965299',
#                                              'kilometers': '54288547.903431313',
#                                              'lunar': '141.1667501311',
#                                              'miles': '33733339.4314575994'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '88002.1188429376',
#                                                  'kilometers_per_second': '24.4450330119',
#                                                  'miles_per_hour': '54681.0943443797'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 4074.0375731972,
#                                   'estimated_diameter_min': 1821.9649913114},
#                          'kilometers': {'estimated_diameter_max': 1.2417666126,
#                                         'estimated_diameter_min': 0.5553349116},
#                          'meters': {'estimated_diameter_max': 1241.766612574,
#                                     'estimated_diameter_min': 555.334911581},
#                          'miles': {'estimated_diameter_max': 0.7715977618,
#                                    'estimated_diameter_min': 0.3450690093}},
#   'id': '2436325',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2436325?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '436325 (2010 GR7)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2436325',
#   'neo_reference_id': '2436325'},
#  {'absolute_magnitude_h': 20.96,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 03:24',
#                            'epoch_date_close_approach': 1673234640000,
#                            'miss_distance': {'astronomical': '0.1211162012',
#                                              'kilometers': '18118725.722011444',
#                                              'lunar': '47.1142022668',
#                                              'miles': '11258454.1022041672'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '22658.3508544674',
#                                                  'kilometers_per_second': '6.2939863485',
#                                                  'miles_per_hour': '14079.0180628772'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1253.2134002046,
#                                   'estimated_diameter_min': 560.4540706342},
#                          'kilometers': {'estimated_diameter_max': 0.3819794322,
#                                         'estimated_diameter_min': 0.1708263953},
#                          'meters': {'estimated_diameter_max': 381.979432159,
#                                     'estimated_diameter_min': 170.8263952629},
#                          'miles': {'estimated_diameter_max': 0.2373509417,
#                                    'estimated_diameter_min': 0.1061465681}},
#   'id': '2508908',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2508908?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '508908 (2003 YX1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2508908',
#   'neo_reference_id': '2508908'},
#  {'absolute_magnitude_h': 21.3,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 07:10',
#                            'epoch_date_close_approach': 1673248200000,
#                            'miss_distance': {'astronomical': '0.4928732055',
#                                              'kilometers': '73732781.722872285',
#                                              'lunar': '191.7276769395',
#                                              'miles': '45815426.073056133'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '121198.8588141982',
#                                                  'kilometers_per_second': '33.6663496706',
#                                                  'miles_per_hour': '75308.2575781889'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1071.581062656,
#                                   'estimated_diameter_min': 479.2256199},
#                          'kilometers': {'estimated_diameter_max': 0.3266178974,
#                                         'estimated_diameter_min': 0.1460679643},
#                          'meters': {'estimated_diameter_max': 326.6178974458,
#                                     'estimated_diameter_min': 146.0679642714},
#                          'miles': {'estimated_diameter_max': 0.2029508896,
#                                    'estimated_diameter_min': 0.090762397}},
#   'id': '3014110',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3014110?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '(1998 SU4)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3014110',
#   'neo_reference_id': '3014110'},
#  {'absolute_magnitude_h': 25.2,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 23:16',
#                            'epoch_date_close_approach': 1673306160000,
#                            'miss_distance': {'astronomical': '0.0850918498',
#                                              'kilometers': '12729559.484439926',
#                                              'lunar': '33.1007295722',
#                                              'miles': '7909781.4821899388'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '36346.123842818',
#                                                  'kilometers_per_second': '10.0961455119',
#                                                  'miles_per_hour': '22584.0678955555'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 177.8381901842,
#                                   'estimated_diameter_min': 79.5316564495},
#                          'kilometers': {'estimated_diameter_max': 0.0542050786,
#                                         'estimated_diameter_min': 0.0242412481},
#                          'meters': {'estimated_diameter_max': 54.2050786336,
#                                     'estimated_diameter_min': 24.2412481101},
#                          'miles': {'estimated_diameter_max': 0.0336814639,
#                                    'estimated_diameter_min': 0.0150628086}},
#   'id': '3559843',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3559843?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '(2011 EP51)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3559843',
#   'neo_reference_id': '3559843'},
#  {'absolute_magnitude_h': 26.9,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 14:16',
#                            'epoch_date_close_approach': 1673273760000,
#                            'miss_distance': {'astronomical': '0.4272893529',
#                                              'kilometers': '63921577.067518323',
#                                              'lunar': '166.2155582781',
#                                              'miles': '39719026.1940379374'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '16576.4865892554',
#                                                  'kilometers_per_second': '4.6045796081',
#                                                  'miles_per_hour': '10299.9841254181'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 81.2877363957,
#                                   'estimated_diameter_min': 36.3529808636},
#                          'kilometers': {'estimated_diameter_max': 0.0247765013,
#                                         'estimated_diameter_min': 0.0110803882},
#                          'meters': {'estimated_diameter_max': 24.7765012606,
#                                     'estimated_diameter_min': 11.0803882126},
#                          'miles': {'estimated_diameter_max': 0.0153953994,
#                                    'estimated_diameter_min': 0.0068850319}},
#   'id': '3789481',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3789481?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '(2017 WU1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3789481',
#   'neo_reference_id': '3789481'},
#  {'absolute_magnitude_h': 25.4,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 04:18',
#                            'epoch_date_close_approach': 1673237880000,
#                            'miss_distance': {'astronomical': '0.4741066959',
#                                              'kilometers': '70925351.859377733',
#                                              'lunar': '184.4275047051',
#                                              'miles': '44070970.0473813954'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '71419.4248076035',
#                                                  'kilometers_per_second': '19.8387291132',
#                                                  'miles_per_hour': '44377.253153369'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 162.1903570994,
#                                   'estimated_diameter_min': 72.5337327539},
#                          'kilometers': {'estimated_diameter_max': 0.0494356193,
#                                         'estimated_diameter_min': 0.022108281},
#                          'meters': {'estimated_diameter_max': 49.435619262,
#                                     'estimated_diameter_min': 22.1082810359},
#                          'miles': {'estimated_diameter_max': 0.0307178602,
#                                    'estimated_diameter_min': 0.0137374447}},
#   'id': '54054562',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54054562?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '(2020 SA3)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54054562',
#   'neo_reference_id': '54054562'},
#  {'absolute_magnitude_h': 26.1,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 14:29',
#                            'epoch_date_close_approach': 1673274540000,
#                            'miss_distance': {'astronomical': '0.3334722534',
#                                              'kilometers': '49886738.812740258',
#                                              'lunar': '129.7207065726',
#                                              'miles': '30998182.0934332404'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '60765.8145388754',
#                                                  'kilometers_per_second': '16.8793929275',
#                                                  'miles_per_hour': '37757.5140394474'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 117.4965270602,
#                                   'estimated_diameter_min': 52.5460443254},
#                          'kilometers': {'estimated_diameter_max': 0.0358129403,
#                                         'estimated_diameter_min': 0.0160160338},
#                          'meters': {'estimated_diameter_max': 35.8129403019,
#                                     'estimated_diameter_min': 16.0160337979},
#                          'miles': {'estimated_diameter_max': 0.0222531225,
#                                    'estimated_diameter_min': 0.0099518989}},
#   'id': '54104276',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54104276?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '(2021 AA1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54104276',
#   'neo_reference_id': '54104276'},
#  {'absolute_magnitude_h': 27.2,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 14:50',
#                            'epoch_date_close_approach': 1673275800000,
#                            'miss_distance': {'astronomical': '0.1503150963',
#                                              'kilometers': '22486818.235324881',
#                                              'lunar': '58.4725724607',
#                                              'miles': '13972660.9305341178'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '33590.9419665386',
#                                                  'kilometers_per_second': '9.3308172129',
#                                                  'miles_per_hour': '20872.1050235973'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 70.7986587106,
#                                   'estimated_diameter_min': 31.6621227185},
#                          'kilometers': {'estimated_diameter_max': 0.0215794305,
#                                         'estimated_diameter_min': 0.0096506147},
#                          'meters': {'estimated_diameter_max': 21.5794304844,
#                                     'estimated_diameter_min': 9.6506146958},
#                          'miles': {'estimated_diameter_max': 0.0134088323,
#                                    'estimated_diameter_min': 0.0059966121}},
#   'id': '54130489',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54130489?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '(2021 EP1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54130489',
#   'neo_reference_id': '54130489'},
#  {'absolute_magnitude_h': 23.39,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 23:18',
#                            'epoch_date_close_approach': 1673306280000,
#                            'miss_distance': {'astronomical': '0.1990572251',
#                                              'kilometers': '29778536.883070537',
#                                              'lunar': '77.4332605639',
#                                              'miles': '18503524.7992939306'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '42454.2341018916',
#                                                  'kilometers_per_second': '11.7928428061',
#                                                  'miles_per_hour': '26379.4100729226'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 409.2842476221,
#                                   'estimated_diameter_min': 183.0374799606},
#                          'kilometers': {'estimated_diameter_max': 0.1247498347,
#                                         'estimated_diameter_min': 0.0557898221},
#                          'meters': {'estimated_diameter_max': 124.7498346832,
#                                     'estimated_diameter_min': 55.7898221067},
#                          'miles': {'estimated_diameter_max': 0.0775159295,
#                                    'estimated_diameter_min': 0.0346661776}},
#   'id': '54174525',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54174525?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '(2021 OZ)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54174525',
#   'neo_reference_id': '54174525'},
#  {'absolute_magnitude_h': 23.39,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 05:43',
#                            'epoch_date_close_approach': 1673242980000,
#                            'miss_distance': {'astronomical': '0.0364120775',
#                                              'kilometers': '5447169.236274925',
#                                              'lunar': '14.1642981475',
#                                              'miles': '3384714.012146965'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '30422.1248161603',
#                                                  'kilometers_per_second': '8.4505902267',
#                                                  'miles_per_hour': '18903.1252781303'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 409.2842476221,
#                                   'estimated_diameter_min': 183.0374799606},
#                          'kilometers': {'estimated_diameter_max': 0.1247498347,
#                                         'estimated_diameter_min': 0.0557898221},
#                          'meters': {'estimated_diameter_max': 124.7498346832,
#                                     'estimated_diameter_min': 55.7898221067},
#                          'miles': {'estimated_diameter_max': 0.0775159295,
#                                    'estimated_diameter_min': 0.0346661776}},
#   'id': '54201812',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54201812?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '(2021 TL)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54201812',
#   'neo_reference_id': '54201812'}]

# %% [markdown]
# Next we extract just the potentially hazerdous asteroids, using a [list comprehension](https://realpython.com/lessons/list-comprehensions-overview/) that implements a ["filter"](https://youtu.be/hUes6y2b--0):

# %%
hazards = [item for item in neos if item['is_potentially_hazardous_asteroid']==True]
print(f'{len(hazards)} potentially hazardous asteroids identified.')
# Out:
# 3 potentially hazardous asteroids identified.

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, **re-write the "list comprehension" above** as a loop so you understand how it works.
# Notice how this kind of "conditional" list comprehension is a compact way to "filter" items of interest from a large data set.

# %%
# Your code here
hazards = []

for item in neos:
  if item['is_potentially_hazardous_asteroid']==True:
    hazards.append(item)

print(f'{len(hazards)} potentially hazardous asteroids identified.')
pprint(hazards)
# Out:
# 3 potentially hazardous asteroids identified.
# [{'absolute_magnitude_h': 19.64,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 13:59',
#                            'epoch_date_close_approach': 1673272740000,
#                            'miss_distance': {'astronomical': '0.0725377631',
#                                              'kilometers': '10851494.854324597',
#                                              'lunar': '28.2171898459',
#                                              'miles': '6742806.2343975586'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '32387.3201949256',
#                                                  'kilometers_per_second': '8.9964778319',
#                                                  'miles_per_hour': '20124.2212622303'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 2301.5744618737,
#                                   'estimated_diameter_min': 1029.2953904054},
#                          'kilometers': {'estimated_diameter_max': 0.7015198735,
#                                         'estimated_diameter_min': 0.313729225},
#                          'meters': {'estimated_diameter_max': 701.5198735305,
#                                     'estimated_diameter_min': 313.7292249562},
#                          'miles': {'estimated_diameter_max': 0.4359041053,
#                                    'estimated_diameter_min': 0.1949422422}},
#   'id': '2226554',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '226554 (2003 WR21)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2226554',
#   'neo_reference_id': '2226554'},
#  {'absolute_magnitude_h': 20.96,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 03:24',
#                            'epoch_date_close_approach': 1673234640000,
#                            'miss_distance': {'astronomical': '0.1211162012',
#                                              'kilometers': '18118725.722011444',
#                                              'lunar': '47.1142022668',
#                                              'miles': '11258454.1022041672'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '22658.3508544674',
#                                                  'kilometers_per_second': '6.2939863485',
#                                                  'miles_per_hour': '14079.0180628772'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1253.2134002046,
#                                   'estimated_diameter_min': 560.4540706342},
#                          'kilometers': {'estimated_diameter_max': 0.3819794322,
#                                         'estimated_diameter_min': 0.1708263953},
#                          'meters': {'estimated_diameter_max': 381.979432159,
#                                     'estimated_diameter_min': 170.8263952629},
#                          'miles': {'estimated_diameter_max': 0.2373509417,
#                                    'estimated_diameter_min': 0.1061465681}},
#   'id': '2508908',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2508908?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '508908 (2003 YX1)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2508908',
#   'neo_reference_id': '2508908'},
#  {'absolute_magnitude_h': 21.3,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 07:10',
#                            'epoch_date_close_approach': 1673248200000,
#                            'miss_distance': {'astronomical': '0.4928732055',
#                                              'kilometers': '73732781.722872285',
#                                              'lunar': '191.7276769395',
#                                              'miles': '45815426.073056133'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '121198.8588141982',
#                                                  'kilometers_per_second': '33.6663496706',
#                                                  'miles_per_hour': '75308.2575781889'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1071.581062656,
#                                   'estimated_diameter_min': 479.2256199},
#                          'kilometers': {'estimated_diameter_max': 0.3266178974,
#                                         'estimated_diameter_min': 0.1460679643},
#                          'meters': {'estimated_diameter_max': 326.6178974458,
#                                     'estimated_diameter_min': 146.0679642714},
#                          'miles': {'estimated_diameter_max': 0.2029508896,
#                                    'estimated_diameter_min': 0.090762397}},
#   'id': '3014110',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3014110?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#   'name': '(1998 SU4)',
#   'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3014110',
#   'neo_reference_id': '3014110'}]

# %% [markdown]
# ## Fetch Compelte Data for One Asteroid
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.
#
# We can use this `id` to fetch complete orbital and close approach data for the NEO.
#
# For example, this query fetches the complete data set for the first hazardous asteroid...

# %%
id = hazards[0]['id']
print(f'id: {id}')
url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}/?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)
# Out:
# id: 2226554

# %% [markdown]
# Notice that the `miss_distance` field contains the distance (in various units) by which the NEO missed an "orbiting body".
#
# ## Exercise 2
#
# In the code cell below, write a python function that takes a list of "close approach data" as a parameter,
# and returns a 2-tuple with the (date, miss km) of the closest approach to Earth in the list (where "miss km" is the miss distance in km).
#
# Hints:
# * notice the input is a list of dictionaries.  Each dictionary has a 'close_approach_date", "orbiting_body", and 'miss_distance' field.
# * we are only interested in the closest approach to "Earth"
# * use a loop if that is easier to understand - we will look at more compact algorithms to solve this problem in class.
#
# Add at least one unit test to check your work - note the test data only needs dictionaries with the fields your function actually uses.

# %%
# your code here

##### USING JOSEPH'S CODE AND INDEX & MIN FUNCTIONS TO LOCATE DESIRED TUPLE FROM APPROACH_DATES #####
def getClosest(approach_dates):
  distance = [float(date_distance[1]) for date_distance in approach_dates]
  return approach_dates[distance.index(min(distance))]


# close_approach_data = data['close_approach_data']
# approach_dates = [
#     (c['close_approach_date'], c['miss_distance']['kilometers']) 
#       for c in close_approach_data if c['orbiting_body'] == 'Earth'
# ]

# getClosest(approach_dates)
#####


##### ROBERTO'S & SOS' CODE #####
# def getClosest(closeApproachList):
#   closest = closeApproachList[0]
#   for record in closeApproachList:
#     if record['orbiting_body'] == 'Earth':
#       if float(record['miss_distance']['kilometers']) < float(closest['miss_distance']['kilometers']):
#         closest = record

#   result = (closest['close_approach_date'], closest['miss_distance']['kilometers'])
#   return result

# %% [markdown]
# ## OPTIONAL - Take your skills to the next level...
# ## Exercise 3
#
# In the code cell below, write a complete program that:
#  1. fetches the list of NEO's for this week.
#  2. for each NEO, fetch it's complete orbital data and determine its closest approach to Earth
#  3. identify which NEO from this week's data makes the closet approach to earth
#  4. print a nice message with information about the NEO, which it will approach the Earth, and how close it will come.
#
# Hints:
# * you'll need the start and end date - end date is today, see if you can use a [`timedelta`](https://docs.python.org/3/library/datetime.html#timedelta-objects) object to ge the start date (you can do basic "date math" with `timedelta` and `date` objects!)
# * you may need to modify the function we wrote in Ex. 2 to return a triple with the NEO's id included;
# * lots of opportunity here for more practice with list comprehensions

# %%
# your code here
from datetime import timedelta

list_of_NEOs_per_day = []

for i in range(2):
  today = str(datetime.date.today() - timedelta(days = i))

  url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={today}&end_date={today}&api_key={API_KEY}'

  response = requests.request("GET", url, headers={}, data={})

  new_data = json.loads(response.text)
  

  list_of_NEOs_per_day.append(new_data['near_earth_objects'][today])
  pprint(list_of_NEOs_per_day)


### Comprehensive version ###
date_distance_id = [
    (asteroid['close_approach_data'][0]['close_approach_date'], 
     asteroid['close_approach_data'][0]['miss_distance']['kilometers'], 
     asteroid['id']) 
      for each_day_data in list_of_NEOs_per_day 
        for asteroid in each_day_data
    ]

### Normal version for easier understanding ###
# for each_day_data in list_of_NEOs_per_day:
#   for asteroid in each_day_data:
#     date_distance_id.append(
#         (asteroid['close_approach_data'][0]['close_approach_date'], 
#           asteroid['close_approach_data'][0]['miss_distance']['kilometers'], 
#             asteroid['id']) #tuple carrying: close approach date, miss distance in km, and asteroid id
#         )


### Side note: erase the function to see the list of date_distance_id tuples ###
getClosest(date_distance_id)
# Out:
# [[{'absolute_magnitude_h': 20.6,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 02:42',
#                             'epoch_date_close_approach': 1674614520000,
#                             'miss_distance': {'astronomical': '0.3275095677',
#                                               'kilometers': '48994733.732540799',
#                                               'lunar': '127.4012218353',
#                                               'miles': '30443915.8382650662'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '34526.3513978218',
#                                                   'kilometers_per_second': '9.5906531661',
#                                                   'miles_per_hour': '21453.3320671632'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 1479.1936371367,
#                                    'estimated_diameter_min': 661.5155049046},
#                           'kilometers': {'estimated_diameter_max': 0.4508582062,
#                                          'estimated_diameter_min': 0.2016299194},
#                           'meters': {'estimated_diameter_max': 450.8582061718,
#                                      'estimated_diameter_min': 201.6299194428},
#                           'miles': {'estimated_diameter_max': 0.2801502144,
#                                     'estimated_diameter_min': 0.1252869847}},
#    'id': '2467336',
#    'is_potentially_hazardous_asteroid': True,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2467336?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '467336 (2002 LT38)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2467336',
#    'neo_reference_id': '2467336'},
#   {'absolute_magnitude_h': 21.45,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 11:22',
#                             'epoch_date_close_approach': 1674645720000,
#                             'miss_distance': {'astronomical': '0.2809643406',
#                                               'kilometers': '42031666.899714522',
#                                               'lunar': '109.2951284934',
#                                               'miles': '26117266.7377315236'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '58369.6013366491',
#                                                   'kilometers_per_second': '16.2137781491',
#                                                   'miles_per_hour': '36268.6003416529'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 1000.0576353763,
#                                    'estimated_diameter_min': 447.2393708238},
#                           'kilometers': {'estimated_diameter_max': 0.3048175575,
#                                          'estimated_diameter_min': 0.1363185559},
#                           'meters': {'estimated_diameter_max': 304.8175575085,
#                                      'estimated_diameter_min': 136.3185558649},
#                           'miles': {'estimated_diameter_max': 0.1894047905,
#                                     'estimated_diameter_min': 0.0847043974}},
#    'id': '2484462',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2484462?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '484462 (2008 CM20)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2484462',
#    'neo_reference_id': '2484462'},
#   {'absolute_magnitude_h': 23.2,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 14:28',
#                             'epoch_date_close_approach': 1674656880000,
#                             'miss_distance': {'astronomical': '0.3299300576',
#                                               'kilometers': '49356833.865937312',
#                                               'lunar': '128.3427924064',
#                                               'miles': '30668914.4278344256'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '81818.6536100052',
#                                                   'kilometers_per_second': '22.7274037806',
#                                                   'miles_per_hour': '50838.929516728'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 446.7093369279,
#                                    'estimated_diameter_min': 199.7744887109},
#                           'kilometers': {'estimated_diameter_max': 0.1361570015,
#                                          'estimated_diameter_min': 0.0608912622},
#                           'meters': {'estimated_diameter_max': 136.1570015386,
#                                      'estimated_diameter_min': 60.8912622106},
#                           'miles': {'estimated_diameter_max': 0.0846040122,
#                                     'estimated_diameter_min': 0.0378360645}},
#    'id': '3422254',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3422254?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2008 OC9)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3422254',
#    'neo_reference_id': '3422254'},
#   {'absolute_magnitude_h': 21.84,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 20:05',
#                             'epoch_date_close_approach': 1674677100000,
#                             'miss_distance': {'astronomical': '0.1406704838',
#                                               'kilometers': '21044004.748349506',
#                                               'lunar': '54.7208181982',
#                                               'miles': '13076138.2020389428'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '27649.254605232',
#                                                   'kilometers_per_second': '7.6803485015',
#                                                   'miles_per_hour': '17180.1715629009'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 835.6511785256,
#                                    'estimated_diameter_min': 373.7145681322},
#                           'kilometers': {'estimated_diameter_max': 0.2547064711,
#                                          'estimated_diameter_min': 0.1139081967},
#                           'meters': {'estimated_diameter_max': 254.706471064,
#                                      'estimated_diameter_min': 113.9081967216},
#                           'miles': {'estimated_diameter_max': 0.1582672146,
#                                     'estimated_diameter_min': 0.0707792501}},
#    'id': '3485809',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3485809?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2010 AO60)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3485809',
#    'neo_reference_id': '3485809'},
#   {'absolute_magnitude_h': 25.1,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 08:34',
#                             'epoch_date_close_approach': 1674635640000,
#                             'miss_distance': {'astronomical': '0.0799027102',
#                                               'kilometers': '11953275.253147274',
#                                               'lunar': '31.0821542678',
#                                               'miles': '7427420.8282254212'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '25831.0826551045',
#                                                   'kilometers_per_second': '7.1753007375',
#                                                   'miles_per_hour': '16050.4302197787'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 186.2194458756,
#                                    'estimated_diameter_min': 83.279867942},
#                           'kilometers': {'estimated_diameter_max': 0.0567596853,
#                                          'estimated_diameter_min': 0.0253837029},
#                           'meters': {'estimated_diameter_max': 56.7596852866,
#                                      'estimated_diameter_min': 25.3837029364},
#                           'miles': {'estimated_diameter_max': 0.0352688224,
#                                     'estimated_diameter_min': 0.0157726969}},
#    'id': '3557089',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3557089?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2011 CO14)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3557089',
#    'neo_reference_id': '3557089'},
#   {'absolute_magnitude_h': 24.8,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 07:30',
#                             'epoch_date_close_approach': 1674631800000,
#                             'miss_distance': {'astronomical': '0.2135759502',
#                                               'kilometers': '31950507.233146074',
#                                               'lunar': '83.0810446278',
#                                               'miles': '19853124.5930568612'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '59937.3386662774',
#                                                   'kilometers_per_second': '16.6492607406',
#                                                   'miles_per_hour': '37242.7313507211'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 213.8085311752,
#                                    'estimated_diameter_min': 95.6180819754},
#                           'kilometers': {'estimated_diameter_max': 0.0651688382,
#                                          'estimated_diameter_min': 0.0291443905},
#                           'meters': {'estimated_diameter_max': 65.1688382168,
#                                      'estimated_diameter_min': 29.1443904535},
#                           'miles': {'estimated_diameter_max': 0.0404940262,
#                                     'estimated_diameter_min': 0.018109479}},
#    'id': '3595927',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3595927?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2012 BX1)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3595927',
#    'neo_reference_id': '3595927'},
#   {'absolute_magnitude_h': 23.3,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 01:44',
#                             'epoch_date_close_approach': 1674611040000,
#                             'miss_distance': {'astronomical': '0.4717863622',
#                                               'kilometers': '70578234.880168514',
#                                               'lunar': '183.5248948958',
#                                               'miles': '43855281.5581089332'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '26183.0189373437',
#                                                   'kilometers_per_second': '7.2730608159',
#                                                   'miles_per_hour': '16269.1097391511'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 426.6041048727,
#                                    'estimated_diameter_min': 190.7831555951},
#                           'kilometers': {'estimated_diameter_max': 0.130028927,
#                                          'estimated_diameter_min': 0.058150704},
#                           'meters': {'estimated_diameter_max': 130.0289270043,
#                                      'estimated_diameter_min': 58.1507039646},
#                           'miles': {'estimated_diameter_max': 0.0807962044,
#                                     'estimated_diameter_min': 0.0361331611}},
#    'id': '3730571',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3730571?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2015 TQ237)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3730571',
#    'neo_reference_id': '3730571'},
#   {'absolute_magnitude_h': 26.6,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 10:31',
#                             'epoch_date_close_approach': 1674642660000,
#                             'miss_distance': {'astronomical': '0.2766723588',
#                                               'kilometers': '41389595.564355756',
#                                               'lunar': '107.6255475732',
#                                               'miles': '25718302.1101751928'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '26480.399419875',
#                                                   'kilometers_per_second': '7.3556665055',
#                                                   'miles_per_hour': '16453.8904061995'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 93.330808926,
#                                    'estimated_diameter_min': 41.7388066307},
#                           'kilometers': {'estimated_diameter_max': 0.0284472297,
#                                          'estimated_diameter_min': 0.0127219879},
#                           'meters': {'estimated_diameter_max': 28.4472296503,
#                                      'estimated_diameter_min': 12.7219878539},
#                           'miles': {'estimated_diameter_max': 0.0176762835,
#                                     'estimated_diameter_min': 0.0079050743}},
#    'id': '3771633',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3771633?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2017 FZ2)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3771633',
#    'neo_reference_id': '3771633'},
#   {'absolute_magnitude_h': 25.7,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 03:36',
#                             'epoch_date_close_approach': 1674617760000,
#                             'miss_distance': {'astronomical': '0.2415898366',
#                                               'kilometers': '36141324.969008042',
#                                               'lunar': '93.9784464374',
#                                               'miles': '22457177.9825612996'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '22059.9980406059',
#                                                   'kilometers_per_second': '6.1277772335',
#                                                   'miles_per_hour': '13707.2248936198'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 141.2618956756,
#                                    'estimated_diameter_min': 63.1742402722},
#                           'kilometers': {'estimated_diameter_max': 0.0430566244,
#                                          'estimated_diameter_min': 0.0192555078},
#                           'meters': {'estimated_diameter_max': 43.0566244241,
#                                      'estimated_diameter_min': 19.2555078188},
#                           'miles': {'estimated_diameter_max': 0.0267541378,
#                                     'estimated_diameter_min': 0.0119648141}},
#    'id': '3841756',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3841756?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2019 JN2)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3841756',
#    'neo_reference_id': '3841756'},
#   {'absolute_magnitude_h': 25.4,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 18:00',
#                             'epoch_date_close_approach': 1674669600000,
#                             'miss_distance': {'astronomical': '0.1556630539',
#                                               'kilometers': '23286861.301135193',
#                                               'lunar': '60.5529279671',
#                                               'miles': '14469784.6396959434'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '41516.8262887201',
#                                                   'kilometers_per_second': '11.5324517469',
#                                                   'miles_per_hour': '25796.9413125661'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 162.1903570994,
#                                    'estimated_diameter_min': 72.5337327539},
#                           'kilometers': {'estimated_diameter_max': 0.0494356193,
#                                          'estimated_diameter_min': 0.022108281},
#                           'meters': {'estimated_diameter_max': 49.435619262,
#                                      'estimated_diameter_min': 22.1082810359},
#                           'miles': {'estimated_diameter_max': 0.0307178602,
#                                     'estimated_diameter_min': 0.0137374447}},
#    'id': '3986731',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3986731?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2020 BO)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986731',
#    'neo_reference_id': '3986731'},
#   {'absolute_magnitude_h': 25.78,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 17:41',
#                             'epoch_date_close_approach': 1674668460000,
#                             'miss_distance': {'astronomical': '0.1988406314',
#                                               'kilometers': '29746134.926895118',
#                                               'lunar': '77.3490056146',
#                                               'miles': '18483391.1573359084'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '30885.2532574871',
#                                                   'kilometers_per_second': '8.579237016',
#                                                   'miles_per_hour': '19190.8952810203'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 136.1523149843,
#                                    'estimated_diameter_min': 60.8891663197},
#                           'kilometers': {'estimated_diameter_max': 0.0414992243,
#                                          'estimated_diameter_min': 0.0185590173},
#                           'meters': {'estimated_diameter_max': 41.4992242792,
#                                      'estimated_diameter_min': 18.5590173004},
#                           'miles': {'estimated_diameter_max': 0.0257864145,
#                                     'estimated_diameter_min': 0.0115320351}},
#    'id': '54111251',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54111251?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2021 CO3)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54111251',
#    'neo_reference_id': '54111251'},
#   {'absolute_magnitude_h': 24.65,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 14:20',
#                             'epoch_date_close_approach': 1674656400000,
#                             'miss_distance': {'astronomical': '0.2739404188',
#                                               'kilometers': '40980903.159387956',
#                                               'lunar': '106.5628229132',
#                                               'miles': '25464352.4255315528'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '21236.6185834225',
#                                                   'kilometers_per_second': '5.8990607176',
#                                                   'miles_per_hour': '13195.6089192383'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 229.0999687787,
#                                    'estimated_diameter_min': 102.4566207664},
#                           'kilometers': {'estimated_diameter_max': 0.0698296682,
#                                          'estimated_diameter_min': 0.031228777},
#                           'meters': {'estimated_diameter_max': 69.8296682492,
#                                      'estimated_diameter_min': 31.2287770103},
#                           'miles': {'estimated_diameter_max': 0.0433901308,
#                                     'estimated_diameter_min': 0.0194046564}},
#    'id': '54280494',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54280494?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2022 KK4)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54280494',
#    'neo_reference_id': '54280494'}]]
# [[{'absolute_magnitude_h': 20.6,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 02:42',
#                             'epoch_date_close_approach': 1674614520000,
#                             'miss_distance': {'astronomical': '0.3275095677',
#                                               'kilometers': '48994733.732540799',
#                                               'lunar': '127.4012218353',
#                                               'miles': '30443915.8382650662'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '34526.3513978218',
#                                                   'kilometers_per_second': '9.5906531661',
#                                                   'miles_per_hour': '21453.3320671632'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 1479.1936371367,
#                                    'estimated_diameter_min': 661.5155049046},
#                           'kilometers': {'estimated_diameter_max': 0.4508582062,
#                                          'estimated_diameter_min': 0.2016299194},
#                           'meters': {'estimated_diameter_max': 450.8582061718,
#                                      'estimated_diameter_min': 201.6299194428},
#                           'miles': {'estimated_diameter_max': 0.2801502144,
#                                     'estimated_diameter_min': 0.1252869847}},
#    'id': '2467336',
#    'is_potentially_hazardous_asteroid': True,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2467336?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '467336 (2002 LT38)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2467336',
#    'neo_reference_id': '2467336'},
#   {'absolute_magnitude_h': 21.45,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 11:22',
#                             'epoch_date_close_approach': 1674645720000,
#                             'miss_distance': {'astronomical': '0.2809643406',
#                                               'kilometers': '42031666.899714522',
#                                               'lunar': '109.2951284934',
#                                               'miles': '26117266.7377315236'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '58369.6013366491',
#                                                   'kilometers_per_second': '16.2137781491',
#                                                   'miles_per_hour': '36268.6003416529'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 1000.0576353763,
#                                    'estimated_diameter_min': 447.2393708238},
#                           'kilometers': {'estimated_diameter_max': 0.3048175575,
#                                          'estimated_diameter_min': 0.1363185559},
#                           'meters': {'estimated_diameter_max': 304.8175575085,
#                                      'estimated_diameter_min': 136.3185558649},
#                           'miles': {'estimated_diameter_max': 0.1894047905,
#                                     'estimated_diameter_min': 0.0847043974}},
#    'id': '2484462',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2484462?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '484462 (2008 CM20)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2484462',
#    'neo_reference_id': '2484462'},
#   {'absolute_magnitude_h': 23.2,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 14:28',
#                             'epoch_date_close_approach': 1674656880000,
#                             'miss_distance': {'astronomical': '0.3299300576',
#                                               'kilometers': '49356833.865937312',
#                                               'lunar': '128.3427924064',
#                                               'miles': '30668914.4278344256'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '81818.6536100052',
#                                                   'kilometers_per_second': '22.7274037806',
#                                                   'miles_per_hour': '50838.929516728'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 446.7093369279,
#                                    'estimated_diameter_min': 199.7744887109},
#                           'kilometers': {'estimated_diameter_max': 0.1361570015,
#                                          'estimated_diameter_min': 0.0608912622},
#                           'meters': {'estimated_diameter_max': 136.1570015386,
#                                      'estimated_diameter_min': 60.8912622106},
#                           'miles': {'estimated_diameter_max': 0.0846040122,
#                                     'estimated_diameter_min': 0.0378360645}},
#    'id': '3422254',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3422254?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2008 OC9)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3422254',
#    'neo_reference_id': '3422254'},
#   {'absolute_magnitude_h': 21.84,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 20:05',
#                             'epoch_date_close_approach': 1674677100000,
#                             'miss_distance': {'astronomical': '0.1406704838',
#                                               'kilometers': '21044004.748349506',
#                                               'lunar': '54.7208181982',
#                                               'miles': '13076138.2020389428'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '27649.254605232',
#                                                   'kilometers_per_second': '7.6803485015',
#                                                   'miles_per_hour': '17180.1715629009'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 835.6511785256,
#                                    'estimated_diameter_min': 373.7145681322},
#                           'kilometers': {'estimated_diameter_max': 0.2547064711,
#                                          'estimated_diameter_min': 0.1139081967},
#                           'meters': {'estimated_diameter_max': 254.706471064,
#                                      'estimated_diameter_min': 113.9081967216},
#                           'miles': {'estimated_diameter_max': 0.1582672146,
#                                     'estimated_diameter_min': 0.0707792501}},
#    'id': '3485809',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3485809?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2010 AO60)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3485809',
#    'neo_reference_id': '3485809'},
#   {'absolute_magnitude_h': 25.1,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 08:34',
#                             'epoch_date_close_approach': 1674635640000,
#                             'miss_distance': {'astronomical': '0.0799027102',
#                                               'kilometers': '11953275.253147274',
#                                               'lunar': '31.0821542678',
#                                               'miles': '7427420.8282254212'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '25831.0826551045',
#                                                   'kilometers_per_second': '7.1753007375',
#                                                   'miles_per_hour': '16050.4302197787'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 186.2194458756,
#                                    'estimated_diameter_min': 83.279867942},
#                           'kilometers': {'estimated_diameter_max': 0.0567596853,
#                                          'estimated_diameter_min': 0.0253837029},
#                           'meters': {'estimated_diameter_max': 56.7596852866,
#                                      'estimated_diameter_min': 25.3837029364},
#                           'miles': {'estimated_diameter_max': 0.0352688224,
#                                     'estimated_diameter_min': 0.0157726969}},
#    'id': '3557089',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3557089?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2011 CO14)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3557089',
#    'neo_reference_id': '3557089'},
#   {'absolute_magnitude_h': 24.8,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 07:30',
#                             'epoch_date_close_approach': 1674631800000,
#                             'miss_distance': {'astronomical': '0.2135759502',
#                                               'kilometers': '31950507.233146074',
#                                               'lunar': '83.0810446278',
#                                               'miles': '19853124.5930568612'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '59937.3386662774',
#                                                   'kilometers_per_second': '16.6492607406',
#                                                   'miles_per_hour': '37242.7313507211'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 213.8085311752,
#                                    'estimated_diameter_min': 95.6180819754},
#                           'kilometers': {'estimated_diameter_max': 0.0651688382,
#                                          'estimated_diameter_min': 0.0291443905},
#                           'meters': {'estimated_diameter_max': 65.1688382168,
#                                      'estimated_diameter_min': 29.1443904535},
#                           'miles': {'estimated_diameter_max': 0.0404940262,
#                                     'estimated_diameter_min': 0.018109479}},
#    'id': '3595927',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3595927?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2012 BX1)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3595927',
#    'neo_reference_id': '3595927'},
#   {'absolute_magnitude_h': 23.3,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 01:44',
#                             'epoch_date_close_approach': 1674611040000,
#                             'miss_distance': {'astronomical': '0.4717863622',
#                                               'kilometers': '70578234.880168514',
#                                               'lunar': '183.5248948958',
#                                               'miles': '43855281.5581089332'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '26183.0189373437',
#                                                   'kilometers_per_second': '7.2730608159',
#                                                   'miles_per_hour': '16269.1097391511'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 426.6041048727,
#                                    'estimated_diameter_min': 190.7831555951},
#                           'kilometers': {'estimated_diameter_max': 0.130028927,
#                                          'estimated_diameter_min': 0.058150704},
#                           'meters': {'estimated_diameter_max': 130.0289270043,
#                                      'estimated_diameter_min': 58.1507039646},
#                           'miles': {'estimated_diameter_max': 0.0807962044,
#                                     'estimated_diameter_min': 0.0361331611}},
#    'id': '3730571',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3730571?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2015 TQ237)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3730571',
#    'neo_reference_id': '3730571'},
#   {'absolute_magnitude_h': 26.6,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 10:31',
#                             'epoch_date_close_approach': 1674642660000,
#                             'miss_distance': {'astronomical': '0.2766723588',
#                                               'kilometers': '41389595.564355756',
#                                               'lunar': '107.6255475732',
#                                               'miles': '25718302.1101751928'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '26480.399419875',
#                                                   'kilometers_per_second': '7.3556665055',
#                                                   'miles_per_hour': '16453.8904061995'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 93.330808926,
#                                    'estimated_diameter_min': 41.7388066307},
#                           'kilometers': {'estimated_diameter_max': 0.0284472297,
#                                          'estimated_diameter_min': 0.0127219879},
#                           'meters': {'estimated_diameter_max': 28.4472296503,
#                                      'estimated_diameter_min': 12.7219878539},
#                           'miles': {'estimated_diameter_max': 0.0176762835,
#                                     'estimated_diameter_min': 0.0079050743}},
#    'id': '3771633',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3771633?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2017 FZ2)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3771633',
#    'neo_reference_id': '3771633'},
#   {'absolute_magnitude_h': 25.7,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 03:36',
#                             'epoch_date_close_approach': 1674617760000,
#                             'miss_distance': {'astronomical': '0.2415898366',
#                                               'kilometers': '36141324.969008042',
#                                               'lunar': '93.9784464374',
#                                               'miles': '22457177.9825612996'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '22059.9980406059',
#                                                   'kilometers_per_second': '6.1277772335',
#                                                   'miles_per_hour': '13707.2248936198'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 141.2618956756,
#                                    'estimated_diameter_min': 63.1742402722},
#                           'kilometers': {'estimated_diameter_max': 0.0430566244,
#                                          'estimated_diameter_min': 0.0192555078},
#                           'meters': {'estimated_diameter_max': 43.0566244241,
#                                      'estimated_diameter_min': 19.2555078188},
#                           'miles': {'estimated_diameter_max': 0.0267541378,
#                                     'estimated_diameter_min': 0.0119648141}},
#    'id': '3841756',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3841756?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2019 JN2)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3841756',
#    'neo_reference_id': '3841756'},
#   {'absolute_magnitude_h': 25.4,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 18:00',
#                             'epoch_date_close_approach': 1674669600000,
#                             'miss_distance': {'astronomical': '0.1556630539',
#                                               'kilometers': '23286861.301135193',
#                                               'lunar': '60.5529279671',
#                                               'miles': '14469784.6396959434'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '41516.8262887201',
#                                                   'kilometers_per_second': '11.5324517469',
#                                                   'miles_per_hour': '25796.9413125661'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 162.1903570994,
#                                    'estimated_diameter_min': 72.5337327539},
#                           'kilometers': {'estimated_diameter_max': 0.0494356193,
#                                          'estimated_diameter_min': 0.022108281},
#                           'meters': {'estimated_diameter_max': 49.435619262,
#                                      'estimated_diameter_min': 22.1082810359},
#                           'miles': {'estimated_diameter_max': 0.0307178602,
#                                     'estimated_diameter_min': 0.0137374447}},
#    'id': '3986731',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3986731?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2020 BO)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986731',
#    'neo_reference_id': '3986731'},
#   {'absolute_magnitude_h': 25.78,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 17:41',
#                             'epoch_date_close_approach': 1674668460000,
#                             'miss_distance': {'astronomical': '0.1988406314',
#                                               'kilometers': '29746134.926895118',
#                                               'lunar': '77.3490056146',
#                                               'miles': '18483391.1573359084'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '30885.2532574871',
#                                                   'kilometers_per_second': '8.579237016',
#                                                   'miles_per_hour': '19190.8952810203'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 136.1523149843,
#                                    'estimated_diameter_min': 60.8891663197},
#                           'kilometers': {'estimated_diameter_max': 0.0414992243,
#                                          'estimated_diameter_min': 0.0185590173},
#                           'meters': {'estimated_diameter_max': 41.4992242792,
#                                      'estimated_diameter_min': 18.5590173004},
#                           'miles': {'estimated_diameter_max': 0.0257864145,
#                                     'estimated_diameter_min': 0.0115320351}},
#    'id': '54111251',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54111251?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2021 CO3)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54111251',
#    'neo_reference_id': '54111251'},
#   {'absolute_magnitude_h': 24.65,
#    'close_approach_data': [{'close_approach_date': '2023-01-25',
#                             'close_approach_date_full': '2023-Jan-25 14:20',
#                             'epoch_date_close_approach': 1674656400000,
#                             'miss_distance': {'astronomical': '0.2739404188',
#                                               'kilometers': '40980903.159387956',
#                                               'lunar': '106.5628229132',
#                                               'miles': '25464352.4255315528'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '21236.6185834225',
#                                                   'kilometers_per_second': '5.8990607176',
#                                                   'miles_per_hour': '13195.6089192383'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 229.0999687787,
#                                    'estimated_diameter_min': 102.4566207664},
#                           'kilometers': {'estimated_diameter_max': 0.0698296682,
#                                          'estimated_diameter_min': 0.031228777},
#                           'meters': {'estimated_diameter_max': 69.8296682492,
#                                      'estimated_diameter_min': 31.2287770103},
#                           'miles': {'estimated_diameter_max': 0.0433901308,
#                                     'estimated_diameter_min': 0.0194046564}},
#    'id': '54280494',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54280494?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2022 KK4)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54280494',
#    'neo_reference_id': '54280494'}],
#  [{'absolute_magnitude_h': 21.954,
#    'close_approach_data': [{'close_approach_date': '2023-01-24',
#                             'close_approach_date_full': '2023-Jan-24 16:59',
#                             'epoch_date_close_approach': 1674579540000,
#                             'miss_distance': {'astronomical': '0.1972456344',
#                                               'kilometers': '29507526.773038728',
#                                               'lunar': '76.7285517816',
#                                               'miles': '18335126.9256333264'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '62821.7234108039',
#                                                   'kilometers_per_second': '17.4504787252',
#                                                   'miles_per_hour': '39034.975860452'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 792.9120720304,
#                                    'estimated_diameter_min': 354.601058648},
#                           'kilometers': {'estimated_diameter_max': 0.2416795918,
#                                          'estimated_diameter_min': 0.1080823992},
#                           'meters': {'estimated_diameter_max': 241.6795918211,
#                                      'estimated_diameter_min': 108.0823992173},
#                           'miles': {'estimated_diameter_max': 0.1501726896,
#                                     'estimated_diameter_min': 0.0671592685}},
#    'id': '3511355',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3511355?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2010 DJ77)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3511355',
#    'neo_reference_id': '3511355'},
#   {'absolute_magnitude_h': 20.1,
#    'close_approach_data': [{'close_approach_date': '2023-01-24',
#                             'close_approach_date_full': '2023-Jan-24 02:42',
#                             'epoch_date_close_approach': 1674528120000,
#                             'miss_distance': {'astronomical': '0.4597041453',
#                                               'kilometers': '68770760.967050511',
#                                               'lunar': '178.8249125217',
#                                               'miles': '42732169.3479026118'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '81875.029519395',
#                                                   'kilometers_per_second': '22.7430637554',
#                                                   'miles_per_hour': '50873.9593144263'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 1862.1944587557,
#                                    'estimated_diameter_min': 832.7986794202},
#                           'kilometers': {'estimated_diameter_max': 0.5675968529,
#                                          'estimated_diameter_min': 0.2538370294},
#                           'meters': {'estimated_diameter_max': 567.5968528656,
#                                      'estimated_diameter_min': 253.8370293645},
#                           'miles': {'estimated_diameter_max': 0.3526882241,
# ...
#                                                   'miles_per_hour': '28881.1057337737'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 245.4850393757,
#                                    'estimated_diameter_min': 109.7842471007},
#                           'kilometers': {'estimated_diameter_max': 0.0748238376,
#                                          'estimated_diameter_min': 0.0334622374},
#                           'meters': {'estimated_diameter_max': 74.8238376074,
#                                      'estimated_diameter_min': 33.4622374455},
#                           'miles': {'estimated_diameter_max': 0.0464933628,
#                                     'estimated_diameter_min': 0.0207924639}},
#    'id': '3778084',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3778084?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2017 OO1)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3778084',
#    'neo_reference_id': '3778084'},
#   {'absolute_magnitude_h': 25.4,
#    'close_approach_data': [{'close_approach_date': '2023-01-24',
#                             'close_approach_date_full': '2023-Jan-24 20:52',
#                             'epoch_date_close_approach': 1674593520000,
#                             'miss_distance': {'astronomical': '0.2641697079',
#                                               'kilometers': '39519225.620362173',
#                                               'lunar': '102.7620163731',
#                                               'miles': '24556108.1186290674'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '32363.5435251652',
#                                                   'kilometers_per_second': '8.9898732014',
#                                                   'miles_per_hour': '20109.4473642895'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 162.1903570994,
#                                    'estimated_diameter_min': 72.5337327539},
#                           'kilometers': {'estimated_diameter_max': 0.0494356193,
#                                          'estimated_diameter_min': 0.022108281},
#                           'meters': {'estimated_diameter_max': 49.435619262,
#                                      'estimated_diameter_min': 22.1082810359},
#                           'miles': {'estimated_diameter_max': 0.0307178602,
#                                     'estimated_diameter_min': 0.0137374447}},
#    'id': '3825159',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3825159?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2018 LS3)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3825159',
#    'neo_reference_id': '3825159'},
#   {'absolute_magnitude_h': 22.6,
#    'close_approach_data': [{'close_approach_date': '2023-01-24',
#                             'close_approach_date_full': '2023-Jan-24 16:36',
#                             'epoch_date_close_approach': 1674578160000,
#                             'miss_distance': {'astronomical': '0.3160411638',
#                                               'kilometers': '47279084.936801106',
#                                               'lunar': '122.9400127182',
#                                               'miles': '29377861.1102070228'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '18031.5088434229',
#                                                   'kilometers_per_second': '5.0087524565',
#                                                   'miles_per_hour': '11204.0783699591'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 588.8775935812,
#                                    'estimated_diameter_min': 263.3540659348},
#                           'kilometers': {'estimated_diameter_max': 0.1794898848,
#                                          'estimated_diameter_min': 0.0802703167},
#                           'meters': {'estimated_diameter_max': 179.4898847799,
#                                      'estimated_diameter_min': 80.2703167283},
#                           'miles': {'estimated_diameter_max': 0.1115298092,
#                                     'estimated_diameter_min': 0.049877647}},
#    'id': '3837588',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3837588?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2019 AN2)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837588',
#    'neo_reference_id': '3837588'},
#   {'absolute_magnitude_h': 25.5,
#    'close_approach_data': [{'close_approach_date': '2023-01-24',
#                             'close_approach_date_full': '2023-Jan-24 12:32',
#                             'epoch_date_close_approach': 1674563520000,
#                             'miss_distance': {'astronomical': '0.3959550722',
#                                               'kilometers': '59234035.416816214',
#                                               'lunar': '154.0265230858',
#                                               'miles': '36806322.8761391932'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '45451.1338530023',
#                                                   'kilometers_per_second': '12.6253149592',
#                                                   'miles_per_hour': '28241.5670321613'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 154.8905885541,
#                                    'estimated_diameter_min': 69.2691770164},
#                           'kilometers': {'estimated_diameter_max': 0.0472106499,
#                                          'estimated_diameter_min': 0.0211132445},
#                           'meters': {'estimated_diameter_max': 47.2106498806,
#                                      'estimated_diameter_min': 21.113244479},
#                           'miles': {'estimated_diameter_max': 0.0293353287,
#                                     'estimated_diameter_min': 0.0131191578}},
#    'id': '3837910',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3837910?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2019 AO13)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837910',
#    'neo_reference_id': '3837910'},
#   {'absolute_magnitude_h': 26.1,
#    'close_approach_data': [{'close_approach_date': '2023-01-24',
#                             'close_approach_date_full': '2023-Jan-24 00:59',
#                             'epoch_date_close_approach': 1674521940000,
#                             'miss_distance': {'astronomical': '0.0309785915',
#                                               'kilometers': '4634331.304000105',
#                                               'lunar': '12.0506720935',
#                                               'miles': '2879639.941627249'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '58345.1422027294',
#                                                   'kilometers_per_second': '16.2069839452',
#                                                   'miles_per_hour': '36253.4023870237'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 117.4965270602,
#                                    'estimated_diameter_min': 52.5460443254},
#                           'kilometers': {'estimated_diameter_max': 0.0358129403,
#                                          'estimated_diameter_min': 0.0160160338},
#                           'meters': {'estimated_diameter_max': 35.8129403019,
#                                      'estimated_diameter_min': 16.0160337979},
#                           'miles': {'estimated_diameter_max': 0.0222531225,
#                                     'estimated_diameter_min': 0.0099518989}},
#    'id': '3837987',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3837987?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2019 BO2)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837987',
#    'neo_reference_id': '3837987'},
#   {'absolute_magnitude_h': 26.25,
#    'close_approach_data': [{'close_approach_date': '2023-01-24',
#                             'close_approach_date_full': '2023-Jan-24 04:10',
#                             'epoch_date_close_approach': 1674533400000,
#                             'miss_distance': {'astronomical': '0.0422219244',
#                                               'kilometers': '6316309.957541028',
#                                               'lunar': '16.4243285916',
#                                               'miles': '3924773.0134730664'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '20171.3320921223',
#                                                   'kilometers_per_second': '5.6031478034',
#                                                   'miles_per_hour': '12533.6813213523'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 109.6541392077,
#                                    'estimated_diameter_min': 49.0388218565},
#                           'kilometers': {'estimated_diameter_max': 0.0334225806,
#                                          'estimated_diameter_min': 0.0149470324},
#                           'meters': {'estimated_diameter_max': 33.422580561,
#                                      'estimated_diameter_min': 14.9470324236},
#                           'miles': {'estimated_diameter_max': 0.0207678223,
#                                     'estimated_diameter_min': 0.0092876525}},
#    'id': '3838075',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3838075?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2019 BZ4)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3838075',
#    'neo_reference_id': '3838075'},
#   {'absolute_magnitude_h': 26.1,
#    'close_approach_data': [{'close_approach_date': '2023-01-24',
#                             'close_approach_date_full': '2023-Jan-24 12:05',
#                             'epoch_date_close_approach': 1674561900000,
#                             'miss_distance': {'astronomical': '0.2288453954',
#                                               'kilometers': '34234783.711147798',
#                                               'lunar': '89.0208588106',
#                                               'miles': '21272508.1787956924'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '40725.1481554256',
#                                                   'kilometers_per_second': '11.3125411543',
#                                                   'miles_per_hour': '25305.0233080199'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 117.4965270602,
#                                    'estimated_diameter_min': 52.5460443254},
#                           'kilometers': {'estimated_diameter_max': 0.0358129403,
#                                          'estimated_diameter_min': 0.0160160338},
#                           'meters': {'estimated_diameter_max': 35.8129403019,
#                                      'estimated_diameter_min': 16.0160337979},
#                           'miles': {'estimated_diameter_max': 0.0222531225,
#                                     'estimated_diameter_min': 0.0099518989}},
#    'id': '3989284',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3989284?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2020 BW12)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989284',
#    'neo_reference_id': '3989284'},
#   {'absolute_magnitude_h': 21.61,
#    'close_approach_data': [{'close_approach_date': '2023-01-24',
#                             'close_approach_date_full': '2023-Jan-24 18:42',
#                             'epoch_date_close_approach': 1674585720000,
#                             'miss_distance': {'astronomical': '0.3393189281',
#                                               'kilometers': '50761388.894443147',
#                                               'lunar': '131.9950630309',
#                                               'miles': '31541664.4525915486'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '36865.4819117645',
#                                                   'kilometers_per_second': '10.2404116422',
#                                                   'miles_per_hour': '22906.7768023405'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 929.0199281072,
#                                    'estimated_diameter_min': 415.4703423399},
#                           'kilometers': {'estimated_diameter_max': 0.283165265,
#                                          'estimated_diameter_min': 0.1266353563},
#                           'meters': {'estimated_diameter_max': 283.1652650258,
#                                      'estimated_diameter_min': 126.6353562929},
#                           'miles': {'estimated_diameter_max': 0.1759506839,
#                                     'estimated_diameter_min': 0.078687538}},
#    'id': '54217965',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54217965?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2021 VP6)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54217965',
#    'neo_reference_id': '54217965'},
#   {'absolute_magnitude_h': 27.16,
#    'close_approach_data': [{'close_approach_date': '2023-01-24',
#                             'close_approach_date_full': '2023-Jan-24 17:37',
#                             'epoch_date_close_approach': 1674581820000,
#                             'miss_distance': {'astronomical': '0.36102541',
#                                               'kilometers': '54008632.3518767',
#                                               'lunar': '140.43888449',
#                                               'miles': '33559407.97303046'},
#                             'orbiting_body': 'Earth',
#                             'relative_velocity': {'kilometers_per_hour': '28935.3035131069',
#                                                   'kilometers_per_second': '8.0375843092',
#                                                   'miles_per_hour': '17979.2723412414'}}],
#    'estimated_diameter': {'feet': {'estimated_diameter_max': 72.1149040484,
#                                    'estimated_diameter_min': 32.2507655286},
#                           'kilometers': {'estimated_diameter_max': 0.0219806221,
#                                          'estimated_diameter_min': 0.009830033},
#                           'meters': {'estimated_diameter_max': 21.9806220506,
#                                      'estimated_diameter_min': 9.8300330186},
#                           'miles': {'estimated_diameter_max': 0.0136581211,
#                                     'estimated_diameter_min': 0.0061080974}},
#    'id': '54248647',
#    'is_potentially_hazardous_asteroid': False,
#    'is_sentry_object': False,
#    'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54248647?api_key=ZA3bIx22Y3t1Rjhdcr5WiHYXPQMQILrXT8xMwnpc'},
#    'name': '(2022 DO4)',
#    'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54248647',
#    'neo_reference_id': '54248647'}]]
# ('2023-01-24', '4634331.304000105', '3837987')

# %% [markdown]
# LAB 3
#
# EX 1
#
# Using what we learned in the textbook, define a simple Asteroid class with some basic state variables for a single NEO. Your Asteroid class should define at least 4 "state variables:”
# id, name, estimated_diameter (m), is_potentially_hazardous (bool)
#
#  Provide an __init__(self, ...) method to initialize a new Asteroid object with specific data values and __str__(self), __repr__(self) methods that returns a nicely formatted string representation of the object...
# OR... use a @dataclass and allow it to supply all that boilerplate code!
#
#  Provide a little code to test your new class.
#
# EX 2
#
# We want to be able to construct Asteroid objects easily from the NEO API. Define a “@classmethod”: from_NEO(cls, neo_id) that takes the id for a single NEO, fetches the
# NEO record from API, constructs and returns an Asteroid object representing that NEO.
# This kind of method is sometimes called a “Factory” – it constructs an object from raw materials

# %%
from dataclasses import dataclass
from datetime import datetime

# %%
@dataclass
class Asteroid:
  id: int
  name: str
  estimated_diameter: float #max estimated diameter in meters
  is_potentially_dangerous: bool
  CloseApproach_objects : list

  @classmethod
  def from_NEO(cls, neo_id):
    id = str(neo_id)
    url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}/?api_key={API_KEY}'
    response = requests.request("GET", url, headers={}, data={})
    data = json.loads(response.text)
    data_record = data['close_approach_data']
    
    ### EX 4 ###
    CloseApproach_objects = [
        CloseApproach.fromRecord(neo_id, record)
        for record in data_record
    ]

    return Asteroid(neo_id, 
                    data['name'], 
                    float(data['estimated_diameter']['meters']['estimated_diameter_max']), 
                    data['is_potentially_hazardous_asteroid'],
                    CloseApproach_objects)


other = Asteroid.from_NEO(2467336)
pprint(other.CloseApproach_objects)
# Out:
# [CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1901, 4, 13), miss_distance=28665449.757554963, relative_velocity=12.5972210283),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1901, 10, 16), miss_distance=58209172.43835018, relative_velocity=12.79485039),
#  CloseApproach(asteroid=2467336, orbiting_body='Venus', approach_date=datetime.date(1902, 9, 1), miss_distance=16973838.068637215, relative_velocity=10.609925095),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1904, 12, 28), miss_distance=56472349.17113622, relative_velocity=13.2073900921),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1905, 6, 29), miss_distance=22542668.041965805, relative_velocity=12.1939995424),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1908, 4, 12), miss_distance=18957868.779189408, relative_velocity=10.032389534),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1908, 10, 4), miss_distance=55803168.11369031, relative_velocity=11.4252485787),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1911, 12, 19), miss_distance=58413696.48278194, relative_velocity=14.1065231028),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1912, 6, 27), miss_distance=33875329.29088117, relative_velocity=14.5647784468),
#  CloseApproach(asteroid=2467336, orbiting_body='Venus', approach_date=datetime.date(1914, 3, 16), miss_distance=21308777.584628683, relative_velocity=9.3209683693),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1915, 4, 15), miss_distance=13866274.486497762, relative_velocity=7.8247036752),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1915, 9, 24), miss_distance=52645144.45193008, relative_velocity=9.7544908257),
#  CloseApproach(asteroid=2467336, orbiting_body='Venus', approach_date=datetime.date(1917, 5, 20), miss_distance=20691191.919998758, relative_velocity=11.5571639818),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1918, 12, 10), miss_distance=59756438.16507674, relative_velocity=14.7174681808),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1919, 6, 25), miss_distance=44952401.75611325, relative_velocity=16.917001863),
#  CloseApproach(asteroid=2467336, orbiting_body='Venus', approach_date=datetime.date(1920, 7, 22), miss_distance=15008332.361522859, relative_velocity=11.8427917481),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1922, 4, 26), miss_distance=14492708.506103298, relative_velocity=6.6698997834),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1922, 9, 11), miss_distance=48703858.95518551, relative_velocity=7.7520542189),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1925, 12, 2), miss_distance=60565941.77026628, relative_velocity=15.0465820776),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1926, 6, 23), miss_distance=54751932.9605558, relative_velocity=18.9672251189),
#  CloseApproach(asteroid=2467336, orbiting_body='Venus', approach_date=datetime.date(1928, 11, 30), miss_distance=18185854.89389484, relative_velocity=9.9705763772),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1929, 5, 11), miss_distance=15867430.966730325, relative_velocity=6.5628449195),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1929, 8, 24), miss_distance=43451595.78716473, relative_velocity=4.6692487),
#  CloseApproach(asteroid=2467336, orbiting_body='Venus', approach_date=datetime.date(1932, 2, 11), miss_distance=22220374.091642063, relative_velocity=11.5277772878),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1932, 4, 25), miss_distance=74653976.0402704, relative_velocity=22.8674146872),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1932, 11, 23), miss_distance=61066966.93802445, relative_velocity=15.1440928641),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1933, 6, 20), miss_distance=65019371.25157741, relative_velocity=21.166709863),
#  CloseApproach(asteroid=2467336, orbiting_body='Venus', approach_date=datetime.date(1935, 4, 15), miss_distance=16080064.75657414, relative_velocity=10.4751674526),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1936, 5, 27), miss_distance=15206538.887904515, relative_velocity=6.5749761699),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1939, 4, 23), miss_distance=64530201.04182632, relative_velocity=20.6865934139),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1939, 11, 16), miss_distance=61184211.94986996, relative_velocity=15.0410836706),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1943, 2, 7), miss_distance=44473021.21601518, relative_velocity=7.4104421638),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1943, 6, 12), miss_distance=12107053.500986341, relative_velocity=6.5853618168),
#  CloseApproach(asteroid=2467336, orbiting_body='Venus', approach_date=datetime.date(1943, 8, 31), miss_distance=21204803.070715554, relative_velocity=14.1119701098),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(1946, 4, 20), miss_distance=55387587.609436445, relative_velocity=18.6605134727),
#  CloseApproach(asteroid=2467336, orbiting_body='Venus', approach_date=datetime.date(

#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(2200, 4, 19), miss_distance=12565478.236816728, relative_velocity=7.406776711),
#  CloseApproach(asteroid=2467336, orbiting_body='Earth', approach_date=datetime.date(2200, 9, 22), miss_distance=51758902.315516844, relative_velocity=9.3765352346)]

# %% [markdown]
# LAB 3
#
# EX 3
#
# Each NEO comes with a list of “close_approach_data”, where each record in this list represents a single “close approach” to another orbiting body.
#
#  Develop a class named “CloseApproach” to represent a single close approach record. State variables are asteroid (Asteroid object), orbiting body (str), approach date (datetime object!), miss distance (float choose units, document it, and be consistent!), and relative velocity (ditto).
#
#  Define a Factory class method to construct a CloseApproach object from one close approach data record (a dictionary object). This method also takes an Asteroid object as input – the Asteroid to which the close approach data belongs.
# Remember to parse the date/time string into a datetime object.

# %%
@dataclass
class CloseApproach:
  asteroid: Asteroid
  orbiting_body: str
  approach_date: datetime.date
  miss_distance: float #in km
  relative_velocity: float #in km/s

  @classmethod
  def fromRecord(cls, Asteroid, record):    
    return CloseApproach(Asteroid, 
                         record['orbiting_body'], 
                         datetime.strptime(record['close_approach_date'], "%Y-%m-%d").date(), 
                         float(record['miss_distance']['kilometers']), 
                         float(record['relative_velocity']['kilometers_per_second'])
                         )

# %%
### testing CloseApproach and its class method ###
id = str(other.id)

url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}/?api_key={API_KEY}'
response = requests.request("GET", url, headers={}, data={})
data = json.loads(response.text)

close_approach_data_0 = data['close_approach_data'][0]
data_record = close_approach_data_0

more_info = CloseApproach.fromRecord(other, data_record)
more_info
# Out:
# CloseApproach(asteroid=Asteroid(id=2467336, name='467336 (2002 LT38)', estimated_diameter=450.8582061718, is_potentially_dangerous=True), orbiting_body='Earth', approach_date=datetime.date(1901, 4, 13), miss_distance=28665449.757554963, relative_velocity=12.5972210283)

# %% [markdown]
# LAB 3
#
# EX 4
#
# Every Asteroid should have a list of “close approaches”. Add a new state variable to your Asteroid class, initially an empty list. In the factory method, use a list comprehension to build a list of CloseApproach objects for the Asteroid from the NEO data record.
# Extend your test code to demonstrate this new feature.

# %% [markdown]
# LAB 3
#
# OPTIONAL
#
# With this data structure in place, we can now start answering all kinds of interesting questions about a single Asteroid or a set of Asteroids. Here’s a couple ideas to try:
#
#  add a method to the Asteroid class, closest_earth_approach, that returns the CloseApproach object that represents the closest approach the Asteroid makes to Earth.
#
#  write a function named "most_dangerous_approach", that takes a date range and returns a single “potentially hazardous” Asteroid object that makes the closest approach to Earth in within that range. Your algorithm will ultimately need to:
#
# ◦ grab the list of NEO’s for the given date range;
#
# ◦ use a list comprehension to build the list of Asteroid objects for the NEO’s returned
#
# ◦ use a list comprehension to filter potentially hazardous Asteroids only;
#
# ◦ use a list comprehension to map each Asteroid to its closest_earth_approach
#
# ◦ apply Python’s min function to identify the Asteroid with the closest_earth_approach
# You may want to decompose some of these steps into smaller functions.
#
#  add a method to the Asteroid class, estimated_mass, that computes an estimate of the
# Asteroid’s mass based on its diameter. This is a model – state your assumptions.
#
#  add a method to the CloseApproach class, impact_force, that estimates the force of impact if the Asteroid hit the orbiting object. Again, this is a model, state your assumptions.

# %%
@dataclass
class Hello:
  hi: str
  # language: str

  @classmethod
  def greeting(cls, first_string, sec_string):
    jambo = first_string + sec_string
    return cls(jambo)

# %%
trial = Hello.greeting("Habari", " yako")
# trial2 = Hello('Hola', 'Spanish')
type(trial)
# print(trial.hi)
# print(type(trial2))
